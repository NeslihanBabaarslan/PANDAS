# %% [markdown]
# <a href="https://colab.research.google.com/github/Nil1205/PANDAS/blob/main/titanic_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("pokemon.csv", index_col=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-8a0c367b635e> in <module>()
# ----> 1 sns.load_dataset.name
#
# AttributeError: 'function' object has no attribute 'name'

# %%
df=pd.read_csv("Pokemon.csv",index_col=0)
df
# Out:
#            Name   Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# #                                        ...
# 1     Bulbasaur    Grass  Poison    318  ...       65     45      1      False
# 2       Ivysaur    Grass  Poison    405  ...       80     60      2      False
# 3      Venusaur    Grass  Poison    525  ...      100     80      3      False
# 4    Charmander     Fire     NaN    309  ...       50     65      1      False
# 5    Charmeleon     Fire     NaN    405  ...       65     80      2      False
# ..          ...      ...     ...    ...  ...      ...    ...    ...        ...
# 147     Dratini   Dragon     NaN    300  ...       50     50      1      False
# 148   Dragonair   Dragon     NaN    420  ...       70     70      2      False
# 149   Dragonite   Dragon  Flying    600  ...      100     80      3      False
# 150      Mewtwo  Psychic     NaN    680  ...       90    130      1       True
# ...

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# #                                    ...
# 1   Bulbasaur  Grass  Poison    318  ...       65     45      1      False
# 2     Ivysaur  Grass  Poison    405  ...       80     60      2      False
# 3    Venusaur  Grass  Poison    525  ...      100     80      3      False
# 4  Charmander   Fire     NaN    309  ...       50     65      1      False
# 5  Charmeleon   Fire     NaN    405  ...       65     80      2      False
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %%
len(df.index)
# Out:
# 151

# %%
len(df.columns)
# Out:
# 12

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# #                                    ...
# 1   Bulbasaur  Grass  Poison    318  ...       65     45      1      False
# 2     Ivysaur  Grass  Poison    405  ...       80     60      2      False
# 3    Venusaur  Grass  Poison    525  ...      100     80      3      False
# 4  Charmander   Fire     NaN    309  ...       50     65      1      False
# 5  Charmeleon   Fire     NaN    405  ...       65     80      2      False
#
# [5 rows x 12 columns]

# %%
def renamed(x):
  if "saur" in Name:
    return True
  return False

# %%
df["Name"].apply(renamed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-050d9f28135c> in <module>()
# ----> 1 df["Name"].apply(renamed)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4211             else:
#    4212                 values = self.astype(object)._values
# -> 4213                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4214
#    4215         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-92-347eeb032c33> in renamed(x)
#       1 def renamed(x):
# ----> 2   if "saur" in Name:
#       3     return True
#       4   return False
#
# NameError: name 'Name' is not defined

# %%
len(df["Type 1"].unique())
# Out:
# 15

# %%
df["Type 1"].nunique()
# Out:
# 15

# %%
df.Total.sort_values(ascending=False)
# Out:
# #
# 150    680
# 151    600
# 149    600
# 146    580
# 145    580
#       ...
# 14     205
# 11     205
# 129    200
# 13     195
# 10     195
# Name: Total, Length: 151, dtype: int64

# %%
df["Name"].value_counts()
# Out:
# Nidoran       2
# Scyther       1
# Charmeleon    1
# Gastly        1
# Dugtrio       1
#              ..
# Jynx          1
# Blastoise     1
# Arbok         1
# Cubone        1
# Haunter       1
# Name: Name, Length: 150, dtype: int64

# %%
df[df["Total"]>df["Total"].mean()]
# Out:
#           Name   Type 1  Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# #                                       ...
# 3     Venusaur    Grass  Poison    525  ...      100     80      3      False
# 6    Charizard     Fire  Flying    534  ...       85    100      3      False
# 9    Blastoise    Water     NaN    530  ...      105     78      3      False
# 18     Pidgeot   Normal  Flying    479  ...       70    101      3      False
# 20    Raticate   Normal     NaN    413  ...       70     97      2      False
# ..         ...      ...     ...    ...  ...      ...    ...    ...        ...
# 146    Moltres     Fire  Flying    580  ...       85     90      1       True
# 148  Dragonair   Dragon     NaN    420  ...       70     70      2      False
# 149  Dragonite   Dragon  Flying    600  ...      100     80      3      False
# 150     Mewtwo  Psychic     NaN    680  ...       90    130      1       True
# ...

# %%
df[df["Speed"].max()==df["Speed"]]
# Out:
#           Name    Type 1 Type 2  Total  ...  Sp. Def  Speed  Stage  Legendary
# #                                       ...
# 101  Electrode  Electric    NaN    480  ...       80    140      2      False
#
# [1 rows x 12 columns]

# %%
df[df["Speed"].max()==df["Speed"]]["Type 1"]
# Out:
# #
# 101    Electric
# Name: Type 1, dtype: object

# %%
dataset = {
        "Departman":["Bilişim","İnsan Kaynakları","Üretim","Üretim","Bilişim","İnsan Kaynakları"],
        "Çalışan": ["Mustafa","Jale","Kadir","Zeynep","Murat","Ahmet"],
        "Maaş":[3000,3500,2500,4500,4000,2000]
        }

# %%
df=pd.DataFrame(dataset)
df
# Out:
#           Departman  Çalışan  Maaş
# 0           Bilişim  Mustafa  3000
# 1  İnsan Kaynakları     Jale  3500
# 2            Üretim    Kadir  2500
# 3            Üretim   Zeynep  4500
# 4           Bilişim    Murat  4000
# 5  İnsan Kaynakları    Ahmet  2000

# %%
df.groupby("Departman")[["Maaş"]].sum()
# Out:
#                   Maaş
# Departman
# Bilişim           7000
# Üretim            7000
# İnsan Kaynakları  5500

# %%
depgroup=df.groupby("Departman")

# %%
depgroup.sum().loc["Bilişim"]
# Out:
# Maaş    7000
# Name: Bilişim, dtype: int64

# %%
df.groupby("Departman")["Maaş"].sum().loc[["Bilişim"]]
# Out:
# Departman
# Bilişim    7000
# Name: Maaş, dtype: int64

# %%
df.groupby("Çalışan")["Maaş"].sum().loc[["Mustafa"]]
# Out:
# Çalışan
# Mustafa    3000
# Name: Maaş, dtype: int64

# %%
df.groupby("Departman")["Maaş"].sum().loc[["Üretim"]]
# Out:
# Departman
# Üretim    7000
# Name: Maaş, dtype: int64

# %%
df.groupby("Departman")["Maaş"].sum().sum()
# Out:
# 19500

# %%
df
# Out:
#           Departman  Çalışan  Maaş
# 0           Bilişim  Mustafa  3000
# 1  İnsan Kaynakları     Jale  3500
# 2            Üretim    Kadir  2500
# 3            Üretim   Zeynep  4500
# 4           Bilişim    Murat  4000
# 5  İnsan Kaynakları    Ahmet  2000

# %%
df.groupby("Departman").count()
# Out:
#                   Çalışan  Maaş
# Departman
# Bilişim                 2     2
# Üretim                  2     2
# İnsan Kaynakları        2     2

# %%
df.groupby("Departman").max()
# Out:
#                   Çalışan  Maaş
# Departman
# Bilişim           Mustafa  4000
# Üretim             Zeynep  4500
# İnsan Kaynakları     Jale  3500

# %%
df.groupby("Departman").min()
# Out:
#                  Çalışan  Maaş
# Departman
# Bilişim            Murat  3000
# Üretim             Kadir  2500
# İnsan Kaynakları   Ahmet  2000

# %%
df.groupby("Departman").min().loc["Bilişim"]
# Out:
# Çalışan    Murat
# Maaş        3000
# Name: Bilişim, dtype: object

# %%
df.groupby("Departman")["Maaş"].min().loc["Bilişim"]
# Out:
# 3000

# %%
df
# Out:
#           Departman  Çalışan  Maaş
# 0           Bilişim  Mustafa  3000
# 1  İnsan Kaynakları     Jale  3500
# 2            Üretim    Kadir  2500
# 3            Üretim   Zeynep  4500
# 4           Bilişim    Murat  4000
# 5  İnsan Kaynakları    Ahmet  2000

# %%
df.columns
# Out:
# Index(['Departman', 'Çalışan', 'Maaş'], dtype='object')

# %%
df.Maaş.sum()/len(df)
# Out:
# 3250.0

# %%
df.groupby("Departman")["Maaş"].mean().loc[["Bilişim"]]
# Out:
# Departman
# Bilişim    3500
# Name: Maaş, dtype: int64

# %%
soccer.grouby("Last_name")["guaranteed_compensation"].max()

# %%
soccer[soccer["guaranteed_compesation"].max()==soccer["guaranteed_compesation"]]

# %%
from numpy.random import randn

# %%
randn(3,3)
# Out:
# array([[-1.21457537,  1.31885937,  2.09260259],
#        [ 0.51388289,  0.23840982, -1.87860438],
#        [ 0.01599516, -0.06719868,  0.66230817]])

# %%
df=pd.DataFrame(randn(3,3), columns=["Column1", "Column2","Column3"], index="A B C".split())
df
# Out:
#     Column1   Column2   Column3
# A  0.193976  1.066682 -1.092764
# B -0.026569  1.769195  0.701226
# C  0.114444 -0.740363  0.881490

# %%
df.Column1
# Out:
# A    0.193976
# B   -0.026569
# C    0.114444
# Name: Column1, dtype: float64

# %%
df.loc["A"]
# Out:
# Column1    0.193976
# Column2    1.066682
# Column3   -1.092764
# Name: A, dtype: float64

# %%
df
# Out:
#     Column1   Column2   Column3
# A  0.193976  1.066682 -1.092764
# B -0.026569  1.769195  0.701226
# C  0.114444 -0.740363  0.881490

# %%
df[["Column1","Column2"]].loc[["A"]]
# Out:
#     Column1   Column2
# A  0.193976  1.066682

# %%
df
# Out:
#     Column1   Column2   Column3
# A  0.193976  1.066682 -1.092764
# B -0.026569  1.769195  0.701226
# C  0.114444 -0.740363  0.881490

# %%
df[["Column3"]].loc[["C"]]
# Out:
#    Column3
# C  0.88149

# %%
df["Column4"]=pd.Series(randn(3), index=["A", "B", "C"])
df
# Out:
#     Column1   Column2   Column3   Column4
# A  0.193976  1.066682 -1.092764 -0.341440
# B -0.026569  1.769195  0.701226  1.302254
# C  0.114444 -0.740363  0.881490  0.100203

# %%
df["Column5"]= df["Column4"]+df["Column3"]
df
# Out:
#     Column1   Column2   Column3   Column4   Column5
# A  0.193976  1.066682 -1.092764 -0.341440 -1.434205
# B -0.026569  1.769195  0.701226  1.302254  2.003481
# C  0.114444 -0.740363  0.881490  0.100203  0.981693

# %%
df.drop("Column5", axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-124-3c69a604621a> in <module>()
# ----> 1 df.drop("Column5", axis=1, inplace=True)
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
df
# Out:
#     Column1   Column2   Column3   Column4
# A  0.193976  1.066682 -1.092764 -0.341440
# B -0.026569  1.769195  0.701226  1.302254
# C  0.114444 -0.740363  0.881490  0.100203

# %%
df.loc["A":"B", "Column1":"Column2"]
# Out:
#     Column1   Column2
# A  0.193976  1.066682
# B -0.026569  1.769195

# %%
df["Column1"]["A"]
# Out:
# 0.19397553743578597

# %%
df.loc["A", "Column1"]
# Out:
# 0.19397553743578597

# %%
df.loc["Column1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Column1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-5060edca9247> in <module>()
# ----> 1 df.loc["Column1"]
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
df.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
len(df.columns)
# Out:
# 15

# %%
len(df.index)
# Out:
# 891

# %%
df_number=df.select_dtypes(include=["float64","int64"])
df_number
# Out:
#      survived  pclass   age  sibsp  parch     fare
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
df_number[["age","fare"]].agg(["min","max"])
# Out:
#        age      fare
# min   0.42    0.0000
# max  80.00  512.3292

# %%
df_number.agg(["count"])
# Out:
#        survived  pclass  age  sibsp  parch  fare
# count       891     891  714    891    891   891

# %%
df_number.agg(["mean","median"])
# Out:
#         survived    pclass        age     sibsp     parch       fare
# mean    0.383838  2.308642  29.699118  0.523008  0.381594  32.204208
# median  0.000000  3.000000  28.000000  0.000000  0.000000  14.454200

# %%
df_number.agg({"survived":"mean","pclass":"min","age":"max"})
# Out:
# survived     0.383838
# pclass       1.000000
# age         80.000000
# dtype: float64

# %%
def f(x):
  return x.mean()-x.std()

# %%
df_number.agg(f)
# Out:
# survived    -0.102754
# pclass       1.472571
# age         15.172620
# sibsp       -0.579736
# parch       -0.424464
# fare       -17.489221
# dtype: float64

# %%
f(df_number)
# Out:
# survived    -0.102754
# pclass       1.472571
# age         15.172620
# sibsp       -0.579736
# parch       -0.424464
# fare       -17.489221
# dtype: float64

# %%
df_number.agg([f,"std","mean"])
# Out:
#       survived    pclass        age     sibsp     parch       fare
# f    -0.102754  1.472571  15.172620 -0.579736 -0.424464 -17.489221
# std   0.486592  0.836071  14.526497  1.102743  0.806057  49.693429
# mean  0.383838  2.308642  29.699118  0.523008  0.381594  32.204208

# %%
fonk=["max","mean","std"]

# %%
df_number.age.agg(fonk)
# Out:
# max     80.000000
# mean    29.699118
# std     14.526497
# Name: age, dtype: float64

# %%
df_number.agg(fonk)
# Out:
#       survived    pclass        age     sibsp     parch        fare
# max   1.000000  3.000000  80.000000  8.000000  6.000000  512.329200
# mean  0.383838  2.308642  29.699118  0.523008  0.381594   32.204208
# std   0.486592  0.836071  14.526497  1.102743  0.806057   49.693429

# %%
df=sns.load_dataset("titanic")

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
#
# [3 rows x 15 columns]

# %%
df.groupby("pclass").mean()
# Out:
#         survived        age     sibsp  ...       fare  adult_male     alone
# pclass                                 ...
# 1       0.629630  38.233441  0.416667  ...  84.154687    0.550926  0.504630
# 2       0.472826  29.877630  0.402174  ...  20.662183    0.538043  0.565217
# 3       0.242363  25.140620  0.615071  ...  13.675550    0.649695  0.659878
#
# [3 rows x 7 columns]

# %%
df.head(2)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
#
# [2 rows x 15 columns]

# %%
df.groupby("who")[["sex"]].count()
# Out:
#        sex
# who
# child   83
# man    537
# woman  271

# %%
df.head(2)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
#
# [2 rows x 15 columns]

# %%
nots=df.survived.unique()[0]

# %%
df.groupby("survived").count()[["who"]]
# Out:
#           who
# survived
# 0         549
# 1         342

# %%
df.groupby("who").count()[["survived"]]
# Out:
# survived    891
# dtype: int64

# %%
df.groupby("who")["survived"].count().loc[["child"]]
# Out:
# who
# child    83
# Name: survived, dtype: int64

# %%
df[df["survived"]==df.survived.unique()[0]].count()
# Out:
# survived       549
# pclass         549
# sex            549
# age            424
# sibsp          549
# parch          549
# fare           549
# embarked       549
# class          549
# who            549
# adult_male     549
# deck            67
# embark_town    549
# alive          549
# alone          549
# dtype: int64

# %%
df.groupby("who")["not"].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-203-c8a3d3f736f3> in <module>()
# ----> 1 df.groupby("who")["not"].sum()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1608                 stacklevel=2,
#    1609             )
# -> 1610         return super().__getitem__(key)
#    1611
#    1612     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     226         else:
#     227             if key not in self.obj:
# --> 228                 raise KeyError(f"Column not found: {key}")
#     229             return self._gotitem(key, ndim=1)
#     230
#
# KeyError: 'Column not found: not'

# %%
df.groupby("who")["survived"].count().loc[["child"]]
# Out:
# who
# child    83
# Name: survived, dtype: int64

# %%
df.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.who.unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
df.groupby("pclass")[["survived"]].count()
# Out:
#         survived
# pclass
# 1            216
# 2            184
# 3            491

# %%
df.groupby("pclass")[["survived"]].mean()
# Out:
#         survived
# pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df.pclass.unique()
# Out:
# array([3, 1, 2])

# %%
df.groupby("sex")["survived"].value_counts()
# Out:
# sex     survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: survived, dtype: int64

# %%
df.groupby("sex")["survived"].value_counts().unstack()
# Out:
# survived    0    1
# sex
# female     81  233
# male      468  109

# %%
df.groupby("who")["survived"].value_counts().loc["child"]
# Out:
# survived
# 1    49
# 0    34
# Name: survived, dtype: int64

# %%
df.groupby("who")["survived"].value_counts().unstack()[0].loc[["child"]]
# Out:
# who
# child    34
# Name: 0, dtype: int64

# %%
df.groupby("sex")["survived"].value_counts().unstack()
# Out:
# survived    0    1
# sex
# female     81  233
# male      468  109

# %%
df.groupby("sex")["survived"].value_counts().unstack().iloc[0,1]
# Out:
# 233

# %%
df.groupby("sex")["survived"].value_counts().unstack()[1].loc[["female"]]
# Out:
# sex
# female    233
# Name: 1, dtype: int64

# %%
df["survived"].groupby([df["sex"],df["pclass"],df["class"]]).value_counts().unstack()
# Out:
# survived                0   1
# sex    pclass class
# female 1      First     3  91
#        2      Second    6  70
#        3      Third    72  72
# male   1      First    77  45
#        2      Second   91  17
#        3      Third   300  47

# %%
df["survived"].groupby([df["sex"],df["pclass"],df["class"]]).value_counts().unstack().loc["female",1].iloc[0,1]
# Out:
# 91

# %%
df.pclass.unique()
# Out:
# array([3, 1, 2])

# %%
df.groupby("sex")[["pclass"]].count()
# Out:
#         pclass
# sex
# female     314
# male       577

# %%
df.head(2)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
#
# [2 rows x 15 columns]

# %%
df.groupby("sex")["survived"].value_counts()

# %%
tot_died=df.groupby("pclass")["survived"].value_counts().unstack()[0].sum()

# %%
df.groupby("sex")["pclass"].value_counts().unstack()
# Out:
# pclass    1    2    3
# sex
# female   94   76  144
# male    122  108  347

# %%
first_died=df.groupby("pclass")["survived"].value_counts().unstack().iloc[0,0]

# %%
first_died/tot_died*100
# Out:
# 14.571948998178508

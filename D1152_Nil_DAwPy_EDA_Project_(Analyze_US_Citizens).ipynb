# %% [markdown]
# <a href="https://colab.research.google.com/github/Nil1205/PANDAS/blob/main/D1152_Nil_DAwPy_EDA_Project_(Analyze_US_Citizens).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="text-align: center"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data from file

# %%
df = pd.read_csv("adult_eda.csv")

# %% [markdown]
# # Try to undersstand what the data looks like? What are types of the features? Are there any missing values? Do I need to eliminate some features?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  ... hours-per-week  native-country salary
# 0   39         State-gov   77516  ...             40   United-States  <=50K
# 1   50  Self-emp-not-inc   83311  ...             13   United-States  <=50K
# 2   38           Private  215646  ...             40   United-States  <=50K
# 3   53           Private  234721  ...             40   United-States  <=50K
# 4   28           Private  338409  ...             40            Cuba  <=50K
#
# [5 rows x 15 columns]

# %%
len(df.index), len(df.columns)
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  ...  32561.000000    32561.000000
# mean      38.581647  1.897784e+05  ...     87.303830       40.437456
# std       13.640433  1.055500e+05  ...    402.960219       12.347429
# min       17.000000  1.228500e+04  ...      0.000000        1.000000
# 25%       28.000000  1.178270e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783560e+05  ...      0.000000       40.000000
# 75%       48.000000  2.370510e+05  ...      0.000000       45.000000
# max       90.000000  1.484705e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# soruyu anlamadım...

# %%
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Look at the value counts of columns that have object datatype and replace '?' like values with 'Unknown' word.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df.select_dtypes("object").agg(["count", "nunique"])
# Out:
#          workclass  education  marital-status  ...    sex  native-country  salary
# count        32561      32561           32561  ...  32561           32561   32561
# nunique          9         16               7  ...      2              42       2
#
# [2 rows x 9 columns]

# %%
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        27493
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
#look at workclass column here
df.workclass.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df["workclass"] = df["workclass"].astype(str).str.replace("\?", "unknown", regex=True)

# %%
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 27      54         ?  180211  Some-college           10.0
# 61      32         ?  293936       7th-8th            4.0
# 69      25         ?  200681  Some-college           10.0
# 77      67         ?  212759          10th            6.0
# 106     17         ?  304873          10th            6.0
# ...    ...       ...     ...           ...            ...
# 32530   35         ?  320084     Bachelors           13.0
# 32531   30         ?   33811     Bachelors           13.0
# 32539   71         ?  287372     Doctorate            NaN
# 32541   41         ?  202822       HS-grad            9.0
# 32542   72         ?  129912       HS-grad            9.0
#
#               marital-status occupation   relationship                race  \
# 27        Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent          ?  Not-in-family               White
# 69             Never-married          ?            NaN               White
# 77        Married-civ-spouse          ?        Husband               White
# 106            Never-married          ?            NaN               White
# ...                      ...        ...            ...                 ...
# 32530     Married-civ-spouse          ?           Wife               White
# 32531          Never-married          ?  Not-in-family  Asian-Pac-Islander
# 32539     Married-civ-spouse          ?        Husband               White
# 32541              Separated          ?  Not-in-family               Black
# 32542     Married-civ-spouse          ?        Husband               White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country  \
# 27       Male             0             0              60          South
# 61       Male             0             0              40              ?
# 69       Male             0             0              40  United-States
# 77       Male             0             0               2  United-States
# 106    Female         34095             0              32  United-States
# ...       ...           ...           ...             ...            ...
# 32530  Female             0             0              55  United-States
# 32531  Female             0             0              99  United-States
# 32539    Male             0             0              10  United-States
# 32541  Female             0             0              32  United-States
# 32542    Male             0             0              25  United-States
#
#       salary
# 27      >50K
# 61     <=50K
# 69     <=50K
# 77     <=50K
# 106    <=50K
# ...      ...
# 32530   >50K
# 32531  <=50K
# 32539   >50K
# 32541  <=50K
# 32542  <=50K
#
# [1836 rows x 15 columns]

# %%
df.workclass.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
#replace all '?' in whole df with 'Unknown'

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Do education and education_num columns hold similar information? If so drop the appropriate choice between them.

# %%
df.education
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
#             ...
# 32556    Assoc-acdm
# 32557       HS-grad
# 32558       HS-grad
# 32559       HS-grad
# 32560       HS-grad
# Name: education, Length: 32561, dtype: object

# %%
df["education-num"]
# Out:
# 0        13.0
# 1        13.0
# 2         9.0
# 3         7.0
# 4        13.0
#          ...
# 32556    12.0
# 32557     9.0
# 32558     9.0
# 32559     9.0
# 32560     9.0
# Name: education-num, Length: 32561, dtype: float64

# %%
df.groupby(["education","education-num"])["salary"].count()
# Out:
# education     education-num
# 10th          6.0                916
# 11th          7.0               1146
# 12th          8.0                424
# 1st-4th       2.0                161
# 5th-6th       3.0                330
# 7th-8th       4.0                631
# 9th           5.0                503
# Assoc-acdm    12.0              1044
# Assoc-voc     11.0              1343
# Bachelors     13.0              5247
# Doctorate     16.0               405
# HS-grad       9.0              10215
# Masters       14.0              1687
# Preschool     1.0                 50
# Prof-school   15.0               559
# Some-college  10.0              7098
# Name: salary, dtype: int64

# %%
df.groupby("education-num")["salary"].count().sort_values(ascending=False)
# Out:
# education-num
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: salary, dtype: int64

# %%
# Out:
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: education-num, dtype: int64

# %%
#drop one of them here

# %% [markdown]
# soruyu anlamadım

# %%
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Take a look at correlation between variables and also see if there are some outliers in any of the columns.

# %%
df.drop("education-num", axis=1, inplace=True)

# %%
df.corr()
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076646      0.077674      0.057775        0.068756
# fnlwgt         -0.076646  1.000000      0.000432     -0.010252       -0.018768
# capital-gain    0.077674  0.000432      1.000000     -0.031615        0.078409
# capital-loss    0.057775 -0.010252     -0.031615      1.000000        0.054256
# hours-per-week  0.068756 -0.018768      0.078409      0.054256        1.000000

# %%
df.describe()
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  32561.000000  32561.000000    32561.000000
# mean      38.581647  1.897784e+05   1077.648844     87.303830       40.437456
# std       13.640433  1.055500e+05   7385.292085    402.960219       12.347429
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.178270e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.783560e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.370510e+05      0.000000      0.000000       45.000000
# max       90.000000  1.484705e+06  99999.000000   4356.000000       99.000000

# %%
q3=df.age.quantile(0.75)
q3
# Out:
# 48.0

# %%
#age column
IQR=df.age.quantile(0.75)-df.age.quantile(0.25)
IQR
# Out:
# 20.0

# %%
upper_lim= q3+1.5*IQR
upper_lim
# Out:
# 78.0

# %%
df[df["age"] >=upper_lim]["age"].value_counts()
# Out:
# 90    43
# 78    23
# 79    22
# 80    22
# 81    20
# 82    12
# 84    10
# 83     6
# 88     3
# 85     3
# 86     1
# 87     1
# Name: age, dtype: int64

# %%
fig ,ax = plt.subplots(2,3,figsize=(20,7))
x = 0
y = 0
for column in df.select_dtypes('number').columns:
    
    df[column].plot(kind = "box", ax = ax[x,y])
    if y < 2:
        y += 1
    else:
        x += 1
        y = 0

# %%
df[(df["hours-per-week"] == 99)].sample(10)
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 30036   40           Private   25005  ...             99  United-States   >50K
# 15534   29           Private  167716  ...             99  United-States  <=50K
# 26858   66           Private  262285  ...             99  United-States  <=50K
# 27222   32         Local-gov  113838  ...             99  United-States  <=50K
# 10143   35           unknown  164866  ...             99  United-States  <=50K
# 1172    25           Private  404616  ...             99  United-States   >50K
# 4441    43      Self-emp-inc  286750  ...             99  United-States   >50K
# 4308    35  Self-emp-not-inc  166416  ...             99  United-States  <=50K
# 15356   90           Private   90523  ...             99  United-States  <=50K
# 27764   38  Self-emp-not-inc  152621  ...             99  United-States  <=50K
#
# [10 rows x 14 columns]

# %%
q3_h=df["hours-per-week"].quantile(0.75)
q3_h
# Out:
# 45.0

# %%
q1_h=df["hours-per-week"].quantile(0.25)
q1_h
# Out:
# 40.0

# %%
#hours per week column
IQR_h=q3_h-q1_h
IQR_h
# Out:
# 5.0

# %%
upper_lim_h=q3_h+1.5*IQR_h
upper_lim_h
# Out:
# 52.5

# %%
# find outlier values which extends the upper limit in both age and hours-per-week columns

# %%
not_outliers =(df.age >= upper_lim)

# %%
df[not_outliers].sample(10)
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 7481    83           Private  195507  ...             55  United-States  <=50K
# 24043   90  Self-emp-not-inc   82628  ...             12  United-States  <=50K
# 9735    78           Private  180239  ...             40          South  <=50K
# 5370    90         Local-gov  227796  ...             60  United-States   >50K
# 20483   79         Local-gov  146244  ...             40  United-States  <=50K
# 18141   79  Self-emp-not-inc   84979  ...             20  United-States   >50K
# 24238   90           unknown  166343  ...             40  United-States  <=50K
# 11512   90           Private   87285  ...             24  United-States  <=50K
# 21516   78           unknown  292019  ...             20  United-States  <=50K
# 13696   82  Self-emp-not-inc  240491  ...             40           Cuba  <=50K
#
# [10 rows x 14 columns]

# %%
not_outliers_h =(df["hours-per-week"] >= upper_lim_h)

# %%
df[not_outliers_h].sample(10)
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 17117   35           Private  209609  ...             60  United-States  <=50K
# 18396   49  Self-emp-not-inc  208872  ...             98  United-States  <=50K
# 14917   35           Private  113481  ...             60  United-States  <=50K
# 26625   67  Self-emp-not-inc  152102  ...             65  United-States  <=50K
# 2422    29           Private  121523  ...             60  United-States  <=50K
# 23106   54      Self-emp-inc  162439  ...             98  United-States   >50K
# 28366   30           Private  206322  ...             73  United-States   >50K
# 20164   53           Private  375134  ...             60  United-States   >50K
# 20477   34           Private  213226  ...             65  United-States   >50K
# 2994    35  Self-emp-not-inc  361888  ...             60          Japan  <=50K
#
# [10 rows x 14 columns]

# %% [markdown]
# # After looking at the outliers you can drop the rows which actually does not make any sense.
# ** Hint: You can check age and hours per week columns. **

# %%
drop_index=df.loc[(df["age"]>=upper_lim)|(df["hours-per-week"]>=upper_lim_h)].index
drop_index
# Out:
# Int64Index([   10,    20,    27,    28,    52,    53,    54,    64,    72,
#                74,
#             ...
#             32500, 32506, 32520, 32523, 32525, 32530, 32531, 32532, 32536,
#             32548],
#            dtype='int64', length=3648)

# %%
df.drop(drop_index, inplace=True)

# %%
# check outlier values which extends the upper limit in both age and hours-per-week columns
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
df.sample(10)
# Out:
#        age workclass  fnlwgt  ... hours-per-week native-country salary
# 17099   23   Private  151888  ...             40  United-States  <=50K
# 459     32   unknown  115745  ...             40  United-States  <=50K
# 5056    26   Private  330695  ...             40  United-States  <=50K
# 16718   20   Private  161092  ...             40  United-States  <=50K
# 3902    22   unknown  131230  ...             40  United-States  <=50K
# 12024   67   Private   64148  ...             41  United-States  <=50K
# 17646   41   Private  237452  ...             15           Cuba   >50K
# 32313   41   Private  144460  ...             40          Italy  <=50K
# 10993   23   Private  117583  ...             40  United-States  <=50K
# 10181   43   Private  108945  ...             50  United-States  <=50K
#
# [10 rows x 14 columns]

# %% [markdown]
# # Impute missing values in relationship column with 'Unmarried'. Also replace 'Not-in-family','Other-relative' values in this column with 'Unmarried'?

# %%
df["relationship"]=df["relationship"].fillna("Unmarried")

# %%
df["relationship"].value_counts()
# Out:
# Husband           10987
# Unmarried          8087
# Not-in-family      7421
# Wife               1487
# Other-relative      931
# Name: relationship, dtype: int64

# %%
df["relationship"]=df["relationship"].replace("Other-relative", "Unmarried")

# %%
df["relationship"]=df["relationship"].replace("Not-in-family", "Unmarried")

# %%
df.relationship.value_counts()
# Out:
# Unmarried    16439
# Husband      10987
# Wife          1487
# Name: relationship, dtype: int64

# %% [markdown]
# ---
# # How many of each race are represented in this dataset?
# ---

# %%
race_count=df.race.value_counts()
race_count
# Out:
# White                 24501
# Black                  2959
# Asian-Pac-Islander      924
# Amer-Indian-Eskimo      278
# Other                   251
# Name: race, dtype: int64

# %%
race_count.sort_values().plot.barh();

# %% [markdown]
# ---
# # What is the average age of men/women?
# ---

# %%
average_age_men=df.groupby("sex")["age"].mean()[1]
average_age_men
# Out:
# 38.990811474971956

# %%
round(average_age_men,1)
# Out:
# 39.0

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Male", "age"].value_counts().plot.bar();

# %%
average_age_women=df.groupby("sex")["age"].mean()[0]
average_age_women
# Out:
# 36.49225034333922

# %%
round(average_age_women,1)
# Out:
# 36.5

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Female", "age"].value_counts().plot.bar();

# %% [markdown]
# ---
# # What is the percentage of people who have a Bachelor's degree?
# ---

# %%
education_list=df.education.value_counts()
education_list
# Out:
# HS-grad         9486
# Some-college    6584
# Bachelors       4616
# Masters         1423
# Assoc-voc       1226
# 11th            1097
# Assoc-acdm       953
# 10th             859
# 7th-8th          566
# 9th              490
# 12th             411
# Prof-school      400
# 5th-6th          308
# Doctorate        296
# 1st-4th          150
# Preschool         48
# Name: education, dtype: int64

# %%
upper=education_list.max()
upper
# Out:
# 9486

# %%
lower=education_list.min()
lower
# Out:
# 48

# %%
percentage_bachelors = (upper/lower) * 100

percentage_bachelors
# Out:
# 19762.5

# %%
df["education"].value_counts(normalize=True)
# Out:
# HS-grad         0.328088
# Some-college    0.227718
# Bachelors       0.159651
# Masters         0.049217
# Assoc-voc       0.042403
# 11th            0.037941
# Assoc-acdm      0.032961
# 10th            0.029710
# 7th-8th         0.019576
# 9th             0.016947
# 12th            0.014215
# Prof-school     0.013835
# 5th-6th         0.010653
# Doctorate       0.010238
# 1st-4th         0.005188
# Preschool       0.001660
# Name: education, dtype: float64

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc["Bachelors"]*100
round(percentage_bachelors,1)
# Out:
# 16.4

# %%
print(f"The percentage of people who have a Bachelor's degree : %{round(percentage_bachelors,1)}")
# Out:
# The percentage of people who have a Bachelor's degree : %16.4

# %% [markdown]
# ---
# # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# ---

# %%
df.groupby(df["education"]==df["education"].isin(["Bachelors", "Masters", "Doctorate"]))["salary"].value_counts()[0]
# Out:
# salary
# <=50K    22552
# >50K      6361
# Name: salary, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         9486
# Some-college    6584
# Bachelors       4616
# Masters         1423
# Assoc-voc       1226
# 11th            1097
# Assoc-acdm       953
# 10th             859
# 7th-8th          566
# 9th              490
# 12th             411
# Prof-school      400
# 5th-6th          308
# Doctorate        296
# 1st-4th          150
# Preschool         48
# Name: education, dtype: int64

# %%
higher_education = df["education"].isin(["Bachelors", "Masters", "Doctorate"])
higher_education
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 28913, dtype: bool

# %%
df_high_edu =df[(df["education"].isin(["Bachelors", "Masters", "Doctorate"]))]
df_high_edu
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 0       39         State-gov   77516  ...             40  United-States  <=50K
# 1       50  Self-emp-not-inc   83311  ...             13  United-States  <=50K
# 4       28           Private  338409  ...             40           Cuba  <=50K
# 5       37           Private  284582  ...             40  United-States  <=50K
# 8       31           Private   45781  ...             50  United-States   >50K
# ...    ...               ...     ...  ...            ...            ...    ...
# 32538   38           Private  139180  ...             45  United-States   >50K
# 32539   71           unknown  287372  ...             10  United-States   >50K
# 32544   31           Private  199655  ...             30  United-States  <=50K
# 32553   32           Private  116138  ...             11         Taiwan  <=50K
# 32554   53           Private  321865  ...             40  United-States   >50K
#
# [6335 rows x 14 columns]

# %%
df[(df["education"].isin(["Bachelors", "Masters", "Doctorate"]))& (df["salary"]== ">50K")]
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 8       31           Private   45781  ...             50  United-States   >50K
# 9       42           Private  159449  ...             40  United-States   >50K
# 11      30         State-gov  141297  ...             40          India   >50K
# 19      43  Self-emp-not-inc  292175  ...             45  United-States   >50K
# 25      56         Local-gov  216851  ...             40  United-States   >50K
# ...    ...               ...     ...  ...            ...            ...    ...
# 32513   46           Private   42972  ...             22  United-States   >50K
# 32533   54           Private  337992  ...             50          Japan   >50K
# 32538   38           Private  139180  ...             45  United-States   >50K
# 32539   71           unknown  287372  ...             10  United-States   >50K
# 32554   53           Private  321865  ...             40  United-States   >50K
#
# [2796 rows x 14 columns]

# %%
high_edu_index=df[(df["education"].isin(["Bachelors", "Masters", "Doctorate"]))& (df["salary"]== ">50K")].index
high_edu_index
# Out:
# Int64Index([    8,     9,    11,    19,    25,    45,    63,    89,    94,
#               100,
#             ...
#             32457, 32458, 32464, 32480, 32504, 32513, 32533, 32538, 32539,
#             32554],
#            dtype='int64', length=2796)

# %%
high_count=len(high_edu_index)
high_count
# Out:
# 2796

# %%
tot_count=len(df.education.index)
tot_count
# Out:
# 28913

# %%
perc_high_edu =high_count/tot_count
perc_high_edu
# Out:
# 0.09670390481790198

# %%
print(f"Percentage of people with advanced education make more than 50K : {round(perc_high_edu * 100, 2)}")
# Out:
# Percentage of people with advanced education make more than 50K : 10.7

# %% [markdown]
# ---
# # What percentage of people without advanced education make more than 50K?
# ---

# %%
lower_education=(~df["education"].isin(["Bachelors", "Masters", "Doctorate"]))

# %%
df_low_edu = df[lower_education]
df_low_edu
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 2       38           Private  215646  ...             40  United-States  <=50K
# 3       53           Private  234721  ...             40  United-States  <=50K
# 6       49           Private  160187  ...             16        Jamaica  <=50K
# 7       52  Self-emp-not-inc  209642  ...             45  United-States   >50K
# 13      32           Private  205019  ...             50  United-States  <=50K
# ...    ...               ...     ...  ...            ...            ...    ...
# 32556   27           Private  257302  ...             38  United-States  <=50K
# 32557   40           Private  154374  ...             40  United-States   >50K
# 32558   58           Private  151910  ...             40  United-States  <=50K
# 32559   22           Private  201490  ...             20  United-States  <=50K
# 32560   52      Self-emp-inc  287927  ...             40  United-States   >50K
#
# [22578 rows x 14 columns]

# %%
lower_education_1=df[(~df["education"].isin(["Bachelors", "Masters", "Doctorate"]))&(df["salary"]>="50K")]
lower_education_1
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 2       38           Private  215646  ...             40  United-States  <=50K
# 3       53           Private  234721  ...             40  United-States  <=50K
# 6       49           Private  160187  ...             16        Jamaica  <=50K
# 7       52  Self-emp-not-inc  209642  ...             45  United-States   >50K
# 13      32           Private  205019  ...             50  United-States  <=50K
# ...    ...               ...     ...  ...            ...            ...    ...
# 32556   27           Private  257302  ...             38  United-States  <=50K
# 32557   40           Private  154374  ...             40  United-States   >50K
# 32558   58           Private  151910  ...             40  United-States  <=50K
# 32559   22           Private  201490  ...             20  United-States  <=50K
# 32560   52      Self-emp-inc  287927  ...             40  United-States   >50K
#
# [22578 rows x 14 columns]

# %%
lower_tot=len(df.loc[(~df["education"].isin(["Bachelors", "Masters", "Doctorate"]))&(df["salary"]>="50K")].index)
lower_tot
# Out:
# 22578

# %%
tot=len(df.education.index)

# %%
perc_low_edu = lower_tot/tot
perc_low_edu
# Out:
# 0.780894407360011

# %%
print(f"Percentage of people without advanced education make more than 50K : {round(perc_low_edu * 100 ,2)}")
# Out:
# Percentage of people without advanced education make more than 50K : 13.38

# %%
if perc_high_edu > perc_low_edu :
    print("More education more money!")
else:
    print("Education has no clear effet on salary. You should investigate some other features also.")
# Out:
# Education has no clear effet on salary. You should investigate some other features also.

# %% [markdown]
# ---
# # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
# ---

# %%
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1471
# 35     1297
#       ...
# 92        1
# 94        1
# 87        1
# 74        1
# 82        1
# Name: hours-per-week, Length: 94, dtype: int64

# %%
lazy_riches = [(df["salary"] == ">50K")&(df["hours-per-week"]=="1")]
lazy_riches
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  32556    False
#  32557    False
#  32558    False
#  32559    False
#  32560    False
#  Length: 28913, dtype: bool]

# %%
df[(df["salary"] == ">50K")&(df["hours-per-week"]=="1")]
# Out:
#        age  workclass  fnlwgt  education      marital-status      occupation  \
# 189     58  State-gov  109567  Doctorate  Married-civ-spouse  Prof-specialty
# 20072   65    Unknown   76043    HS-grad  Married-civ-spouse         Unknown
#
#       relationship   race   sex  capital-gain  capital-loss  hours-per-week  \
# 189        Husband  White  Male             0             0               1
# 20072      Husband  White  Male             0             0               1
#
#       native-country salary
# 189    United-States   >50K
# 20072  United-States   >50K

# %%
num_lazy_riches = len(df.loc[(df["salary"] == ">50K")&(df["hours-per-week"]=="1")].index)
num_lazy_riches
# Out:
# 2

# %%
num_min_workers = 
num_min_workers
# Out:
# 20

# %%
print (f"Percentage of the people who work the minimum number of hours per week have a salary of >50K : % {round(num_lazy_riches/num_min_workers*100)}")
# Out:
# Percentage of the people who work the minimum number of hours per week have a salary of >50K : % 10

# %% [markdown]
# hocam sonuçlarım baştan beri yanlış geldiği için kesişimim boş küme çıktı ama olması gereken formulleri yazdım yinede.

# %% [markdown]
#  ---
#  # What country has the highest percentage of people that earn >50K?
#  ---

# %%
country_salary_df =df.groupby("native-country")[["salary"]].count()
country_salary_df
# Out:
#                             salary
# native-country
# ?                              505
# Cambodia                        19
# Canada                         102
# China                           71
# Columbia                        57
# Cuba                            88
# Dominican-Republic              62
# Ecuador                         24
# El-Salvador                    102
# England                         76
# France                          25
# Germany                        122
# Greece                          20
# Guatemala                       63
# Haiti                           41
# Holand-Netherlands               1
# Honduras                        12
# Hong                            19
# Hungary                         10
# India                           88
# Iran                            34
# Ireland                         20
# Italy                           63
# Jamaica                         76
# Japan                           52
# Laos                            18
# Mexico                         591
# Nicaragua                       33
# Outlying-US(Guam-USVI-etc)      11
# Peru                            30
# Philippines                    185
# Poland                          52
# Portugal                        34
# Puerto-Rico                    107
# Scotland                        10
# South                           61
# Taiwan                          44
# Thailand                        13
# Trinadad&Tobago                 18
# United-States                25878
# Vietnam                         63
# Yugoslavia                      13

# %%
country_salary_df_riches = df[df["salary"] == ">50K"][["native-country"]].value_counts()
country_salary_df_riches
# Out:
# native-country
# United-States         5816
# ?                      116
# Philippines             55
# Germany                 37
# India                   33
# Canada                  30
# Mexico                  26
# England                 24
# Cuba                    20
# Japan                   20
# Italy                   20
# China                   19
# Taiwan                  14
# Iran                    13
# Puerto-Rico             12
# Poland                  11
# Jamaica                 10
# France                  10
# South                   10
# Cambodia                 7
# El-Salvador              6
# Greece                   5
# Hong                     5
# Vietnam                  5
# Portugal                 4
# Yugoslavia               4
# Haiti                    3
# Guatemala                3
# Ecuador                  3
# Ireland                  3
# Peru                     2
# Nicaragua                2
# Laos                     2
# Hungary                  2
# Scotland                 2
# Thailand                 2
# Trinadad&Tobago          2
# Columbia                 2
# Dominican-Republic       1
# dtype: int64

# %%
rich_per_country =
rich_per_country
# Out:
#                               salary
# native-country
# Dominican-Republic          0.028571
# Columbia                    0.033898
# Guatemala                   0.046875
# Mexico                      0.051322
# Nicaragua                   0.058824
# Peru                        0.064516
# Vietnam                     0.074627
# Honduras                    0.076923
# El-Salvador                 0.084906
# Haiti                       0.090909
# Trinadad&Tobago             0.105263
# Puerto-Rico                 0.105263
# Portugal                    0.108108
# Laos                        0.111111
# Jamaica                     0.123457
# Ecuador                     0.142857
# Thailand                    0.166667
# Poland                      0.200000
# South                       0.200000
# Ireland                     0.208333
# Hungary                     0.230769
# United-States               0.245808
# Scotland                    0.250000
# Unknown                     0.250859
# Cuba                        0.263158
# China                       0.266667
# Greece                      0.275862
# Hong                        0.300000
# Philippines                 0.308081
# Germany                     0.321168
# Canada                      0.322314
# England                     0.333333
# Italy                       0.342466
# Cambodia                    0.368421
# Yugoslavia                  0.375000
# Japan                       0.387097
# Taiwan                      0.392157
# India                       0.400000
# France                      0.413793
# Iran                        0.418605
# Holand-Netherlands               NaN
# Outlying-US(Guam-USVI-etc)       NaN

# %%
country_salary_df.loc[["Iran"]]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
#use iloc here
country_salary_df.iloc[[20]]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
plt.figure(figsize=(14,7))
df.loc[df["salary"] == ">50K", "native-country"].value_counts().plot(kind="bar");

# %%
plt.figure(figsize=(12,6))
df.loc[((df["native-country"] == "Iran")), "salary"].value_counts().plot.bar();

# %% [markdown]
# ---
# # Identify the most popular occupation for those who earn >50K in India.
# ---

# %%
top_IN_occupation=[(df["native-country"]=="India")&(df["salary"] ==">50K")]
top_IN_occupation
# Out:
# [0        False
#  1        False
#  2        False
#  3        False
#  4        False
#           ...
#  32556    False
#  32557    False
#  32558    False
#  32559    False
#  32560    False
#  Length: 28913, dtype: bool]

# %%
df[(df["native-country"]=="India")&(df["salary"] ==">50K")]
# Out:
#        age         workclass  fnlwgt  ... hours-per-week native-country salary
# 11      30         State-gov  141297  ...             40          India   >50K
# 968     48           Private  164966  ...             40          India   >50K
# 1327    52           Private  168381  ...             40          India   >50K
# 7285    54         State-gov   93449  ...             40          India   >50K
# 8124    36           Private  172104  ...             40          India   >50K
# 9939    43       Federal-gov  325706  ...             50          India   >50K
# 10590   35           Private   98283  ...             40          India   >50K
# 10661   59           Private  122283  ...             40          India   >50K
# 10736   30           Private  243190  ...             20          India   >50K
# 11260   54           Private  225599  ...             40          India   >50K
# 11384   34           Private   98283  ...             40          India   >50K
# 13422   53           Private  366957  ...             50          India   >50K
# 13551   40           Private  220977  ...             40          India   >50K
# 13862   45           Private  209912  ...             40          India   >50K
# 16017   41           Private  207578  ...             50          India   >50K
# 16778   43           Private  242968  ...             40          India   >50K
# 17259   57      Self-emp-inc  123053  ...             50          India   >50K
# 17834   29  Self-emp-not-inc  341672  ...             50          India   >50K
# 21128   30           Private  122889  ...             50          India   >50K
# 23474   55         State-gov  120781  ...             40          India   >50K
# 24154   46           Private  229737  ...             50          India   >50K
# 25739   35      Self-emp-inc   79586  ...             40          India   >50K
# 26305   27           Private  207352  ...             40          India   >50K
# 26356   34           Private   99872  ...             40          India   >50K
# 27670   61           Private   80896  ...             45          India   >50K
# 28452   53           Private   70387  ...             40          India   >50K
# 28557   34           Private  165737  ...             43          India   >50K
# 28651   45  Self-emp-not-inc  216402  ...             50          India   >50K
# 28798   30  Self-emp-not-inc  116666  ...             50          India   >50K
# 30111   41       Federal-gov  219155  ...             50          India   >50K
# 30152   48           Private  119471  ...             40          India   >50K
# 30833   25           Private  110978  ...             37          India   >50K
# 31357   23           Private  143003  ...             50          India   >50K
#
# [33 rows x 14 columns]

# %%
oc_list=df[(df["native-country"]=="India")&(df["salary"] ==">50K")]["occupation"].value_counts()
oc_list
# Out:
# Prof-specialty      20
# Exec-managerial      7
# Tech-support         2
# Other-service        1
# Transport-moving     1
# Sales                1
# Adm-clerical         1
# Name: occupation, dtype: int64

# %%
a = oc_list.head(1)
a
# Out:
# Prof-specialty    20
# Name: occupation, dtype: int64

# %%
a=df["occupation"].mode()[0]
a
# Out:
# 'Craft-repair'

# %%
print(f"{a} the most popular occupation for those who earn >50K in India.")
# Out:
# Prof-specialty the most popular occupation for those who earn >50K in India.

# %% [markdown]
# ----
# ---
